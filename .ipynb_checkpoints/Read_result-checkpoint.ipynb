# %%
import h5py
import numpy as np
import pandas as pd
from scipy import sparse
import matplotlib.pyplot as plt
import caiman as cm
import json
from caiman.utils.visualization import get_contours

# %%
directory = '/media/david/hdd1/David_GCAMP/20210827'
filename = 'file_00001'

# %%
#Read tag file
dict_name = directory+'/tag/'+filename+'.json'
with open(dict_name, 'r') as f:
    tag = json.load(f)
display_tag = tag.copy()
display_tag.pop('metadata')
print(display_tag)
# Out:
# {'total_volume': 3000, 'framesPerSlice': 1, 'num_slice': 1, 'FrameRate': 29.9979, 'numFramesPerVolume': 1, 'pixelsPerLine': 512, 'linesPerFrame': 512, 'scanZoomFactor': 7, 'stackZStepSize': 5, 'length': 3000}

# %%
#Read results
num_slice = 1
name = directory+'/preprocess/'+filename+'_'+str(num_slice)+'.hdf5'
cnm2 = h5py.File(name,'r')

# %%
#fname_new = '/media/david/hdd1/David_GCAMP/20210820/sliced_data/memmap__d1_512_d2_512_d3_1_order_C_frames_1000_.mmap'
#Yr, dims, T = cm.load_memmap(fname_new)
#images = np.reshape(Yr.T, [T] + list(dims), order='F')

# %%
cnm2['params']['temporal'].keys()
# Out:
# <KeysViewHDF5 ['ITER', 'bas_nonneg', 'block_size_temp', 'fudge_factor', 'lags', 'memory_efficient', 'method_deconvolution', 'nb', 'noise_method', 'noise_range', 'num_blocks_per_run_temp', 'optimize_g', 'p', 's_min', 'solvers', 'verbosity']>

# %%
cnm2['params']['temporal']['nb']
# Out:
# <HDF5 dataset "nb": shape (), type "<i8">

# %%
cnm2['estimates']['idx_components']
# Out:
# array([ 31,  32,  41,  74,  75,  76,  78,  79, 102])

# %%
cnm2['estimates'].keys()
# Out:
# <KeysViewHDF5 ['A', 'A_thr', 'Ab', 'Ab_dense', 'AtA', 'AtY_buf', 'C', 'CC', 'CY', 'C_on', 'Cf', 'F_dff', 'OASISinstances', 'R', 'S', 'SNR_comp', 'W', 'YrA', 'Yr_buf', 'b', 'b0', 'bl', 'c1', 'center', 'cnn_preds', 'dims', 'discarded_components', 'ecc', 'f', 'g', 'idx_components', 'idx_components_bad', 'ind_new', 'lam', 'mn', 'neurons_sn', 'noisyC', 'nr', 'psx', 'r_values', 'rho_buf', 'shifts', 'sn', 'sv', 'vr']>

# %%
#shape, indices, indptr, data are used to produce sparse matrix A
shape = cnm2['estimates']['A']['shape'][:]
indices = cnm2['estimates']['A']['indices'][:]
indptr = cnm2['estimates']['A']['indptr'][:]
data = cnm2['estimates']['A']['data'][:]
#Shape of the picture (pixel*pixel)
dims = cnm2['dims'][:]
#Spatial component (num of pixel^2,num of components)
A = sparse.csr_matrix((data, indices, indptr),shape=(shape[1],shape[0])).transpose()
#Temporal component (num of components, time steps)
C = cnm2['estimates']['C'][:]
#Background spatial component (num of pixel^2,num of components)
b = cnm2['estimates']['b'][:]
#Background temporal component (num of background components, time steps)
f = cnm2['estimates']['f'][:]
#A.dot(C) is spatial-temporal component of neurons, b.dot(f) is spatial-temporal component of background
denoised = (A.dot(C)+b.dot(f)).reshape((dims[0],dims[1])+(-1,),order='F').transpose([2, 0, 1])#denoised movie
denoised_only_neuron = (A.dot(C)).reshape((dims[0],dims[1])+(-1,),order='F').transpose([2, 0, 1])#denoised total neurons
#np.save(directory+'/denoise/''+'denoise_'+filename,denoised)

#Residual components
YrA = cnm2['estimates']['YrA'][:]

#Deconvolved neural activity (spikes)
S = cnm2['estimates']['S'][:]

#DF/F normalized temporal compoment
#F_dff = cnm2['estimates']['F_dff'][:]

#Center of Mass and Neuron shape
coordinate = get_contours(A, dims, thr=0.9)

# %%
coordinate
# Out:
# [{'coordinates': array([[         nan,          nan],
#          [269.        , 183.62244697],
#          [268.85863781, 184.        ],
#          [268.        , 184.91528889],
#          [267.92168264, 185.        ],
#          [267.81009002, 186.        ],
#          [267.        , 186.84717526],
#          [266.86424356, 187.        ],
#          [266.62981375, 188.        ],
#          [266.        , 188.63721654],
#          [265.71094618, 189.        ],
#          [265.        , 189.72107899],
#          [264.70907239, 190.        ],
#          [264.        , 190.72675305],
#          [263.74108618, 191.        ],
#          [263.        , 191.72650134],
#          [262.71473266, 192.        ],
#          [262.        , 192.67468047],
#          [261.        , 192.85633487],
#          [260.        , 192.88591758],
#          [259.        , 192.88476658],
#          [258.        , 192.86333546],
#          [257.13666454, 192.        ],
#          [257.        , 191.82165659],
#          [256.17834341, 191.        ],
#          [256.        , 190.76875059],
#          [255.23124941, 190.        ],
#          [255.        , 189.69645412],
#          [254.30354588, 189.        ],
#          [254.        , 188.08829063],
#          [253.91170937, 188.        ],
#          [253.68201607, 187.        ],
#          [253.67082135, 186.        ],
#          [253.60152751, 185.        ],
#          [253.62945999, 184.        ],
#          [254.        , 183.08115422],
#          [254.13783915, 183.        ],
#          [255.        , 182.18212619],
#          [256.        , 182.39094191],
#          [256.57637167, 182.        ],
#          [256.        , 181.62268184],
#          [255.18140432, 181.        ],
#          [255.06660277, 180.        ],
#          [255.85347654, 179.        ],
#          [256.        , 178.91629357],
#          [257.        , 178.91606634],
#          [257.82368837, 178.        ],
#          [258.        , 177.78419763],
#          [258.51730291, 177.        ],
#          [258.9409609 , 176.        ],
#          [259.        , 175.48728189],
#          [259.03592711, 175.        ],
#          [259.52135291, 174.        ],
#          [260.        , 173.77327078],
#          [260.67507994, 173.        ],
#          [261.        , 172.80449695],
#          [262.        , 172.88035251],
#          [262.15426086, 173.        ],
#          [263.        , 173.38495402],
#          [263.62075791, 174.        ],
#          [264.        , 174.20543851],
#          [264.75894287, 175.        ],
#          [265.        , 175.29580141],
#          [265.70076743, 176.        ],
#          [266.        , 176.41526382],
#          [266.57787806, 177.        ],
#          [267.        , 177.83290392],
#          [267.16194342, 178.        ],
#          [267.86329513, 179.        ],
#          [268.        , 179.1752413 ],
#          [268.79986109, 180.        ],
#          [269.        , 180.42470781],
#          [269.5209718 , 181.        ],
#          [269.57669213, 182.        ],
#          [269.56310838, 183.        ],
#          [269.        , 183.62244697],
#          [         nan,          nan]]),
#   'CoM': array([182.9767979 , 261.50271515]),
#   'neuron_id': 1},
#  {'coordinates': array([[         nan,          nan],
#          [305.        , 215.36417578],
#          [304.70067132, 216.        ],
#          [304.        , 216.72747647],
#          [303.88611663, 217.        ],
#          [303.71157924, 218.        ],
#          [303.33824897, 219.        ],
#          [303.        , 219.34649757],
#          [302.69390951, 220.        ],
#          [302.        , 220.67105249],
#          [301.12272775, 221.        ],
#          [301.        , 221.05353494],
#          [300.        , 221.3422574 ],
#          [299.        , 221.02131844],
#          [298.95641762, 221.        ],
#          [298.        , 220.45175639],
#          [297.        , 220.05478105],
#          [296.85054801, 220.        ],
#          [296.        , 219.60949328],
#          [295.40605746, 219.        ],
#          [295.        , 218.57757938],
#          [294.48703085, 218.        ],
#          [294.        , 217.4327931 ],
#          [293.67526837, 217.        ],
#          [293.5213251 , 216.        ],
#          [293.        , 215.43269623],
#          [292.61120459, 215.        ],
#          [292.        , 214.28182756],
#          [291.66858655, 214.        ],
#          [291.5538487 , 213.        ],
#          [291.23391326, 212.        ],
#          [291.        , 211.6890328 ],
#          [290.39162964, 211.        ],
#          [290.06388354, 210.        ],
#          [290.20721801, 209.        ],
#          [291.        , 208.13147334],
#          [291.29098249, 208.        ],
#          [292.        , 207.3281603 ],
#          [292.7325885 , 207.        ],
#          [293.        , 206.83294964],
#          [293.81472814, 206.        ],
#          [294.        , 205.2154794 ],
#          [294.06247106, 205.        ],
#          [294.99539493, 204.        ],
#          [295.        , 203.99521357],
#          [296.        , 203.53320118],
#          [296.97893919, 204.        ],
#          [297.        , 204.00917056],
#          [297.87887019, 205.        ],
#          [298.        , 205.11344471],
#          [299.        , 205.44308591],
#          [300.        , 205.2195638 ],
#          [300.90108542, 206.        ],
#          [301.        , 206.07712584],
#          [301.62925945, 207.        ],
#          [302.        , 207.42700607],
#          [302.88736465, 208.        ],
#          [303.        , 208.0684746 ],
#          [303.95361213, 209.        ],
#          [303.98381921, 210.        ],
#          [304.        , 210.0523387 ],
#          [304.54657471, 211.        ],
#          [304.56504644, 212.        ],
#          [305.        , 212.79672608],
#          [305.19470951, 213.        ],
#          [305.19247783, 214.        ],
#          [305.33793499, 215.        ],
#          [305.        , 215.36417578],
#          [         nan,          nan]]),
#   'CoM': array([212.23476467, 297.88018649]),
#   'neuron_id': 2},
#  {'coordinates': array([[         nan,          nan],
#          [216.        , 217.16477917],
#          [215.57433346, 218.        ],
#          [215.36541454, 219.        ],
#          [215.        , 219.49085569],
#          [214.57558275, 220.        ],
#          [214.        , 220.58289165],
#          [213.        , 220.5179334 ],
#          [212.        , 220.80784411],
#          [211.        , 220.90547311],
#          [210.89667117, 221.        ],
#          [210.        , 221.69190415],
#          [209.        , 221.74167732],
#          [208.41650082, 222.        ],
#          [208.        , 222.25664191],
#          [207.67133028, 222.        ],
#          [207.        , 221.43533176],
#          [206.53428866, 221.        ],
#          [206.        , 220.66959359],
#          [205.22630546, 220.        ],
#          [205.        , 219.58466644],
#          [204.53173752, 219.        ],
#          [204.        , 218.61152218],
#          [203.43751729, 218.        ],
#          [203.        , 217.58858611],
#          [202.41447527, 217.        ],
#          [202.25839551, 216.        ],
#          [202.28024422, 215.        ],
#          [202.        , 214.06759721],
#          [201.        , 214.01948968],
#          [200.98458186, 214.        ],
#          [200.        , 213.05787788],
#          [199.9264658 , 213.        ],
#          [199.28202079, 212.        ],
#          [199.10214806, 211.        ],
#          [199.10682425, 210.        ],
#          [199.27715694, 209.        ],
#          [199.56942793, 208.        ],
#          [200.        , 207.56942793],
#          [200.58509456, 207.        ],
#          [201.        , 206.58509456],
#          [202.        , 206.36134664],
#          [202.51132511, 206.        ],
#          [203.        , 205.71625032],
#          [204.        , 205.72720398],
#          [205.        , 205.70555266],
#          [206.        , 205.8236355 ],
#          [206.2522422 , 206.        ],
#          [207.        , 206.64160606],
#          [207.36214892, 207.        ],
#          [208.        , 207.68019781],
#          [209.        , 207.91293198],
#          [209.09060724, 208.        ],
#          [210.        , 208.42404229],
#          [210.88685373, 208.        ],
#          [211.        , 207.91490648],
#          [211.21649758, 208.        ],
#          [212.        , 208.23848999],
#          [213.        , 208.28324258],
#          [213.33854686, 209.        ],
#          [213.        , 209.92373845],
#          [212.        , 209.99436552],
#          [211.99421329, 210.        ],
#          [211.50422457, 211.        ],
#          [211.55384265, 212.        ],
#          [212.        , 212.08865015],
#          [212.88770306, 213.        ],
#          [213.        , 213.09081705],
#          [214.        , 213.15158069],
#          [214.64291477, 213.        ],
#          [214.10572355, 212.        ],
#          [214.        , 211.93194237],
#          [213.04851468, 211.        ],
#          [214.        , 210.08665334],
#          [215.        , 210.10176415],
#          [215.59487324, 211.        ],
#          [215.56408795, 212.        ],
#          [215.37013894, 213.        ],
#          [216.        , 213.6915672 ],
#          [216.25719293, 214.        ],
#          [216.44753572, 215.        ],
#          [216.41590071, 216.        ],
#          [216.16846277, 217.        ],
#          [216.        , 217.16477917],
#          [         nan,          nan]]),
#   'CoM': array([213.99295163, 208.08048311]),
#   'neuron_id': 3},
#  {'coordinates': array([[         nan,          nan],
#          [295.        , 239.90779881],
#          [294.96020115, 240.        ],
#          [294.76994385, 241.        ],
#          [294.        , 241.91696844],
#          [293.97487196, 242.        ],
#          [293.65767446, 243.        ],
#          [293.        , 243.70325588],
#          [292.69961147, 244.        ],
#          [292.        , 244.70423242],
#          [291.57641057, 245.        ],
#          [291.        , 245.41214884],
#          [290.04693025, 246.        ],
#          [290.        , 246.04192468],
#          [289.        , 246.780404  ],
#          [288.        , 246.97989726],
#          [287.94541095, 247.        ],
#          [287.        , 247.71555028],
#          [286.        , 247.80235714],
#          [285.        , 247.86047355],
#          [284.        , 247.97354734],
#          [283.        , 247.97593453],
#          [282.        , 247.93218709],
#          [281.        , 247.98674005],
#          [280.        , 247.84850233],
#          [279.        , 247.72424196],
#          [278.        , 247.48339011],
#          [277.        , 247.33596947],
#          [276.        , 247.08021689],
#          [275.66559384, 247.        ],
#          [275.        , 246.63276717],
#          [274.        , 246.09702673],
#          [273.86558506, 246.        ],
#          [273.        , 245.35077397],
#          [272.65592948, 245.        ],
#          [272.        , 244.54908578],
#          [271.4578547 , 244.        ],
#          [271.        , 243.42591663],
#          [270.68094319, 243.        ],
#          [270.44746054, 242.        ],
#          [270.66803774, 241.        ],
#          [271.        , 240.44102376],
#          [271.22565233, 240.        ],
#          [271.41931223, 239.        ],
#          [271.71803256, 238.        ],
#          [272.        , 237.62708886],
#          [272.66204283, 237.        ],
#          [273.        , 236.70585651],
#          [273.5909769 , 236.        ],
#          [274.        , 235.62989258],
#          [274.51233418, 235.        ],
#          [274.67417004, 234.        ],
#          [275.        , 233.70150645],
#          [275.59987042, 233.        ],
#          [276.        , 232.46184474],
#          [276.41037405, 232.        ],
#          [277.        , 231.400348  ],
#          [277.31570501, 231.        ],
#          [277.7243276 , 230.        ],
#          [278.        , 229.71723336],
#          [278.7404046 , 229.        ],
#          [279.        , 228.90774955],
#          [280.        , 228.4706297 ],
#          [281.        , 228.33710606],
#          [282.        , 228.46075758],
#          [283.        , 228.54064867],
#          [284.        , 228.81010494],
#          [285.        , 228.8562259 ],
#          [285.54472462, 229.        ],
#          [286.        , 229.11283063],
#          [287.        , 229.39543866],
#          [288.        , 229.6307141 ],
#          [289.        , 229.74913824],
#          [290.        , 229.99847464],
#          [290.00253852, 230.        ],
#          [290.38234335, 231.        ],
#          [291.        , 231.46022768],
#          [291.14089489, 232.        ],
#          [291.88803954, 233.        ],
#          [292.        , 233.07435291],
#          [293.        , 233.33440703],
#          [294.        , 233.66659559],
#          [294.27453246, 234.        ],
#          [295.        , 234.70748451],
#          [295.23249705, 235.        ],
#          [295.67360743, 236.        ],
#          [295.75996362, 237.        ],
#          [295.72118983, 238.        ],
#          [295.66580672, 239.        ],
#          [295.        , 239.90779881],
#          [         nan,          nan]]),
#   'CoM': array([238.94878441, 282.80157525]),
#   'neuron_id': 4},
#  {'coordinates': array([[         nan,          nan],
#          [244.        , 224.1646546 ],
#          [243.15598273, 225.        ],
#          [243.        , 225.15598273],
#          [242.        , 225.48528858],
#          [241.        , 225.48210439],
#          [240.39312832, 225.        ],
#          [240.        , 224.70227591],
#          [239.15732996, 224.        ],
#          [239.        , 223.81775394],
#          [238.17527232, 223.        ],
#          [238.344267  , 222.        ],
#          [239.        , 221.08138779],
#          [240.        , 221.2962649 ],
#          [240.54149464, 221.        ],
#          [241.        , 220.30006937],
#          [241.17586387, 220.        ],
#          [241.        , 219.81494499],
#          [240.        , 219.4619392 ],
#          [239.16097132, 219.        ],
#          [239.21578315, 218.        ],
#          [239.        , 217.90987401],
#          [238.        , 217.78056396],
#          [237.84318042, 218.        ],
#          [237.93625099, 219.        ],
#          [237.64800052, 220.        ],
#          [237.        , 220.96112802],
#          [236.        , 220.74218832],
#          [235.        , 220.88308445],
#          [234.        , 220.55309624],
#          [233.        , 220.42483842],
#          [232.56993138, 220.        ],
#          [232.        , 219.51064136],
#          [231.        , 219.44261079],
#          [230.52526156, 219.        ],
#          [230.        , 218.5737585 ],
#          [229.        , 218.44980097],
#          [228.48191165, 218.        ],
#          [228.        , 217.60997726],
#          [227.35541228, 217.        ],
#          [227.        , 216.69261638],
#          [226.30443981, 216.        ],
#          [226.        , 215.6928467 ],
#          [225.38665664, 215.        ],
#          [225.22703693, 214.        ],
#          [225.25233564, 213.        ],
#          [225.34004359, 212.        ],
#          [225.42592416, 211.        ],
#          [225.49387141, 210.        ],
#          [225.64419646, 209.        ],
#          [226.        , 208.6105174 ],
#          [226.28453265, 208.        ],
#          [226.39701107, 207.        ],
#          [227.        , 206.25235673],
#          [227.09928283, 206.        ],
#          [227.20690413, 205.        ],
#          [228.        , 204.1908137 ],
#          [228.17501723, 204.        ],
#          [228.28015567, 203.        ],
#          [229.        , 202.27117389],
#          [229.27305722, 202.        ],
#          [230.        , 201.2746434 ],
#          [231.        , 201.04931455],
#          [231.08775193, 201.        ],
#          [232.        , 200.34813668],
#          [233.        , 200.31937761],
#          [234.        , 200.89119897],
#          [234.23186536, 201.        ],
#          [235.        , 201.08434759],
#          [236.        , 201.12128591],
#          [237.        , 201.25805432],
#          [238.        , 201.46581319],
#          [239.        , 201.99409596],
#          [239.00886841, 202.        ],
#          [240.        , 202.96961213],
#          [240.03185838, 203.        ],
#          [240.11102176, 204.        ],
#          [240.17016441, 205.        ],
#          [240.25852078, 206.        ],
#          [241.        , 206.7553039 ],
#          [241.26634366, 207.        ],
#          [241.43716547, 208.        ],
#          [242.        , 208.79893408],
#          [242.28291431, 209.        ],
#          [243.        , 209.87121406],
#          [243.02762509, 210.        ],
#          [243.27023932, 211.        ],
#          [244.        , 211.96129995],
#          [244.03870005, 212.        ],
#          [244.10054811, 213.        ],
#          [244.        , 213.20550774],
#          [243.22282432, 214.        ],
#          [243.        , 214.37866652],
#          [242.69879339, 215.        ],
#          [242.64092321, 216.        ],
#          [242.38534491, 217.        ],
#          [242.48013519, 218.        ],
#          [242.78269189, 219.        ],
#          [242.80558555, 220.        ],
#          [243.        , 220.4065881 ],
#          [243.4501046 , 221.        ],
#          [243.80115397, 222.        ],
#          [244.        , 222.20216167],
#          [244.38514719, 223.        ],
#          [244.1646546 , 224.        ],
#          [244.        , 224.1646546 ],
#          [         nan,          nan],
#          [242.02872565, 222.        ],
#          [242.04566819, 221.        ],
#          [242.        , 220.98342423],
#          [241.96724641, 221.        ],
#          [241.96946282, 222.        ],
#          [242.        , 222.00847916],
#          [242.02872565, 222.        ],
#          [         nan,          nan]]),
#   'CoM': array([211.31695705, 234.45237956]),
#   'neuron_id': 5},
#  {'coordinates': array([[         nan,          nan],
#          [240.        , 334.12418332],
#          [239.57587726, 335.        ],
#          [239.        , 335.74637686],
#          [238.72652808, 336.        ],
#          [238.        , 336.91557238],
#          [237.59117397, 337.        ],
#          [237.        , 337.268891  ],
#          [236.29408303, 338.        ],
#          [236.        , 338.12441311],
#          [235.        , 338.23625126],
#          [234.        , 338.24299561],
#          [233.        , 338.29054278],
#          [232.        , 338.883802  ],
#          [231.        , 338.88220559],
#          [230.        , 338.94250791],
#          [229.80394275, 339.        ],
#          [229.29736305, 340.        ],
#          [229.97098318, 341.        ],
#          [229.75765079, 342.        ],
#          [229.        , 342.62992357],
#          [228.        , 342.7288646 ],
#          [227.        , 342.88336222],
#          [226.        , 342.8838334 ],
#          [225.        , 342.45302219],
#          [224.49534611, 342.        ],
#          [224.        , 341.8858508 ],
#          [223.        , 341.18259666],
#          [222.80078089, 341.        ],
#          [222.        , 340.73746444],
#          [221.17354332, 340.        ],
#          [221.        , 339.94278665],
#          [220.        , 339.73782585],
#          [219.25740825, 339.        ],
#          [219.        , 338.74403348],
#          [218.23920873, 338.        ],
#          [218.0784712 , 337.        ],
#          [218.        , 336.27457365],
#          [217.77191725, 336.        ],
#          [218.        , 335.11738913],
#          [218.00566029, 335.        ],
#          [218.        , 334.40029809],
#          [217.97507547, 334.        ],
#          [218.        , 333.46781492],
#          [218.01930624, 333.        ],
#          [218.98508363, 332.        ],
#          [219.        , 331.97677744],
#          [220.        , 331.08167399],
#          [220.16703046, 331.        ],
#          [220.74885891, 330.        ],
#          [220.79209046, 329.        ],
#          [221.        , 328.08224303],
#          [221.10292849, 328.        ],
#          [222.        , 327.81563639],
#          [222.33213653, 327.        ],
#          [223.        , 326.23429161],
#          [224.        , 326.36301293],
#          [224.58536051, 326.        ],
#          [224.49964137, 325.        ],
#          [224.78663069, 324.        ],
#          [224.80980716, 323.        ],
#          [225.        , 322.37943729],
#          [225.09767611, 322.        ],
#          [225.1182451 , 321.        ],
#          [226.        , 320.13535622],
#          [226.12176585, 320.        ],
#          [227.        , 319.08995875],
#          [227.10973994, 319.        ],
#          [227.74537266, 318.        ],
#          [228.        , 317.74137577],
#          [228.56231714, 317.        ],
#          [229.        , 316.56490722],
#          [230.        , 316.04128224],
#          [230.04077266, 316.        ],
#          [231.        , 315.29912761],
#          [232.        , 315.06457823],
#          [232.10091628, 315.        ],
#          [233.        , 314.19620286],
#          [234.        , 314.11081288],
#          [235.        , 314.14433336],
#          [235.90277939, 315.        ],
#          [236.        , 315.07459795],
#          [237.        , 315.59868447],
#          [237.39984785, 316.        ],
#          [238.        , 316.5932241 ],
#          [238.41800061, 317.        ],
#          [239.        , 317.95538392],
#          [239.03812585, 318.        ],
#          [239.98154412, 319.        ],
#          [239.98419348, 320.        ],
#          [240.        , 320.09886395],
#          [240.52075417, 321.        ],
#          [240.        , 321.7302479 ],
#          [239.95709146, 322.        ],
#          [240.        , 322.18630617],
#          [240.63542784, 323.        ],
#          [240.63516092, 324.        ],
#          [240.82859345, 325.        ],
#          [240.78172326, 326.        ],
#          [240.72620635, 327.        ],
#          [240.51830951, 328.        ],
#          [240.51245994, 329.        ],
#          [240.55650486, 330.        ],
#          [240.57043885, 331.        ],
#          [240.58589687, 332.        ],
#          [240.52054852, 333.        ],
#          [240.10405227, 334.        ],
#          [240.        , 334.12418332],
#          [         nan,          nan]]),
#   'CoM': array([328.96853855, 230.5130094 ]),
#   'neuron_id': 6},
#  {'coordinates': array([[         nan,          nan],
#          [294.        , 306.10658251],
#          [293.22894314, 307.        ],
#          [293.        , 307.38675642],
#          [292.3632861 , 308.        ],
#          [292.        , 308.35486831],
#          [291.        , 308.63911806],
#          [290.        , 308.63700732],
#          [289.        , 308.28798378],
#          [288.        , 308.06923072],
#          [287.82095586, 308.        ],
#          [287.13822907, 307.        ],
#          [287.81770214, 306.        ],
#          [288.        , 305.8576743 ],
#          [288.77866599, 305.        ],
#          [288.075533  , 304.        ],
#          [288.        , 303.92799278],
#          [287.        , 303.46877982],
#          [286.11844311, 303.        ],
#          [286.        , 302.97001965],
#          [285.        , 302.96425001],
#          [284.7247702 , 303.        ],
#          [284.        , 303.22027952],
#          [283.        , 303.92364495],
#          [282.        , 303.65495872],
#          [281.        , 303.69986635],
#          [280.68198142, 304.        ],
#          [280.        , 304.65461729],
#          [279.69035116, 305.        ],
#          [279.        , 305.51345559],
#          [278.        , 305.59180323],
#          [277.01311392, 305.        ],
#          [277.        , 304.99434791],
#          [276.        , 304.01076105],
#          [275.99118405, 304.        ],
#          [275.40890497, 303.        ],
#          [275.22622159, 302.        ],
#          [275.20916409, 301.        ],
#          [275.2119421 , 300.        ],
#          [275.23193938, 299.        ],
#          [275.30864939, 298.        ],
#          [275.36873513, 297.        ],
#          [276.        , 296.23165666],
#          [276.22738522, 296.        ],
#          [277.        , 295.23155388],
#          [278.        , 295.1187364 ],
#          [278.35504753, 295.        ],
#          [279.        , 294.51057458],
#          [280.        , 294.02946716],
#          [280.6755031 , 294.        ],
#          [281.        , 293.9557454 ],
#          [282.        , 293.97456528],
#          [282.03246052, 294.        ],
#          [283.        , 294.58320991],
#          [284.        , 294.85314852],
#          [284.19033202, 295.        ],
#          [285.        , 295.17160225],
#          [286.        , 295.30885221],
#          [287.        , 295.52963673],
#          [287.49836368, 296.        ],
#          [288.        , 296.36798774],
#          [288.82290246, 297.        ],
#          [289.        , 297.14158748],
#          [289.86605275, 298.        ],
#          [290.        , 298.12570784],
#          [291.        , 298.89735237],
#          [291.10274028, 299.        ],
#          [291.89459676, 300.        ],
#          [292.        , 300.14602854],
#          [292.86464591, 301.        ],
#          [292.87874054, 302.        ],
#          [293.        , 302.19474735],
#          [293.53800055, 303.        ],
#          [293.78755231, 304.        ],
#          [294.        , 304.34571002],
#          [294.46394119, 305.        ],
#          [294.10213247, 306.        ],
#          [294.        , 306.10658251],
#          [         nan,          nan]]),
#   'CoM': array([301.05226227, 284.05153718]),
#   'neuron_id': 7},
#  {'coordinates': array([[         nan,          nan],
#          [296.        , 322.27104974],
#          [295.61395656, 323.        ],
#          [295.        , 323.6121218 ],
#          [294.        , 323.95002552],
#          [293.88279675, 324.        ],
#          [293.        , 324.65862516],
#          [292.        , 324.74956125],
#          [291.        , 324.85050666],
#          [290.        , 324.78814728],
#          [289.        , 324.57056413],
#          [288.        , 324.52473734],
#          [287.        , 324.40892649],
#          [286.52802503, 324.        ],
#          [286.        , 323.83600404],
#          [285.        , 323.76479822],
#          [284.        , 323.75970814],
#          [283.        , 323.73697062],
#          [282.        , 323.681706  ],
#          [281.        , 323.16645344],
#          [280.83068589, 323.        ],
#          [280.        , 322.1855113 ],
#          [279.85358304, 322.        ],
#          [279.35701581, 321.        ],
#          [279.26583863, 320.        ],
#          [279.31213629, 319.        ],
#          [279.39384545, 318.        ],
#          [279.56944982, 317.        ],
#          [279.71622076, 316.        ],
#          [279.8947933 , 315.        ],
#          [280.        , 314.82842387],
#          [280.6009819 , 314.        ],
#          [281.        , 313.59041599],
#          [282.        , 313.18678965],
#          [282.14286395, 313.        ],
#          [282.3951777 , 312.        ],
#          [283.        , 311.40320847],
#          [284.        , 311.63791047],
#          [285.        , 311.34587484],
#          [285.46656133, 312.        ],
#          [286.        , 312.51237299],
#          [286.27650036, 313.        ],
#          [286.        , 313.42442104],
#          [285.63458059, 314.        ],
#          [285.20555118, 315.        ],
#          [285.        , 315.29803376],
#          [284.        , 315.14998356],
#          [283.79764584, 316.        ],
#          [284.        , 316.78744868],
#          [285.        , 316.74770108],
#          [285.32247345, 317.        ],
#          [286.        , 317.10540608],
#          [286.29018682, 317.        ],
#          [287.        , 316.50641841],
#          [287.94792244, 317.        ],
#          [288.        , 317.01248646],
#          [288.04943051, 317.        ],
#          [289.        , 316.18434658],
#          [290.        , 316.00108394],
#          [290.00110876, 316.        ],
#          [290.15983409, 315.        ],
#          [290.60468857, 314.        ],
#          [290.5020821 , 313.        ],
#          [290.        , 312.51511511],
#          [289.49755789, 312.        ],
#          [289.06918476, 311.        ],
#          [290.        , 310.34693624],
#          [291.        , 310.60392065],
#          [292.        , 310.51592021],
#          [293.        , 310.07414403],
#          [294.        , 310.04688959],
#          [295.        , 310.51812683],
#          [295.49280729, 311.        ],
#          [295.57935634, 312.        ],
#          [296.        , 312.8789206 ],
#          [296.10115143, 313.        ],
#          [296.28638443, 314.        ],
#          [296.59051089, 315.        ],
#          [296.65393322, 316.        ],
#          [296.73082475, 317.        ],
#          [296.87201112, 318.        ],
#          [296.87783081, 319.        ],
#          [296.8734155 , 320.        ],
#          [296.7613532 , 321.        ],
#          [296.26801591, 322.        ],
#          [296.        , 322.27104974],
#          [         nan,          nan]]),
#   'CoM': array([318.50136114, 289.21357596]),
#   'neuron_id': 8},
#  {'coordinates': array([[         nan,          nan],
#          [215.        , 359.46447662],
#          [214.57425181, 360.        ],
#          [214.22210016, 361.        ],
#          [214.        , 361.22614009],
#          [213.60510989, 362.        ],
#          [213.15775103, 363.        ],
#          [213.        , 363.3509484 ],
#          [212.77469798, 364.        ],
#          [212.        , 364.78764542],
#          [211.93046785, 365.        ],
#          [211.19043006, 366.        ],
#          [211.        , 366.20986388],
#          [210.19409714, 367.        ],
#          [210.        , 367.3060077 ],
#          [209.        , 367.78201471],
#          [208.        , 367.99497768],
#          [207.99285836, 368.        ],
#          [207.01636328, 369.        ],
#          [207.        , 369.00767359],
#          [206.        , 369.28113235],
#          [205.4498051 , 369.        ],
#          [205.        , 368.80933042],
#          [204.        , 368.43408927],
#          [203.        , 368.49102585],
#          [202.        , 368.46195479],
#          [201.        , 368.35147957],
#          [200.        , 368.2562217 ],
#          [199.71491934, 368.        ],
#          [199.        , 367.65519317],
#          [198.23569223, 367.        ],
#          [198.        , 366.88150834],
#          [197.        , 366.44146935],
#          [196.55340397, 366.        ],
#          [196.12859521, 365.        ],
#          [196.92522122, 364.        ],
#          [196.86884168, 363.        ],
#          [196.51960169, 362.        ],
#          [197.        , 361.63584747],
#          [197.42694962, 361.        ],
#          [197.88733789, 360.        ],
#          [198.        , 359.85656444],
#          [198.76822617, 359.        ],
#          [198.78596236, 358.        ],
#          [199.        , 357.5194774 ],
#          [199.11536298, 357.        ],
#          [200.        , 356.48142443],
#          [201.        , 356.4879527 ],
#          [202.        , 356.5013339 ],
#          [203.        , 356.41570946],
#          [204.        , 356.42033938],
#          [204.87088701, 357.        ],
#          [205.        , 357.11343332],
#          [206.        , 357.57433596],
#          [207.        , 357.09221439],
#          [207.24630631, 357.        ],
#          [208.        , 356.58176793],
#          [209.        , 356.13697269],
#          [210.        , 356.19994039],
#          [210.12633853, 356.        ],
#          [211.        , 355.02798268],
#          [211.04935983, 355.        ],
#          [212.        , 354.07623223],
#          [213.        , 354.12598619],
#          [213.81902923, 355.        ],
#          [214.        , 355.62824651],
#          [214.07587929, 356.        ],
#          [214.84262043, 357.        ],
#          [215.        , 357.60111892],
#          [215.10929744, 358.        ],
#          [215.34498128, 359.        ],
#          [215.        , 359.46447662],
#          [         nan,          nan]]),
#   'CoM': array([362.2095888 , 205.91743448]),
#   'neuron_id': 9}]

# %%
#%% Extract DF/F values---Without YrA(Residual components)
#I think f_dff is better than F_dff, but F_dff is closer to real data
FrameRate = tag['FrameRate']
sliding_time = 8
F_dff = cm.source_extraction.cnmf.utilities.detrend_df_f(A, b, C, f,YrA=YrA,quantileMin=10,frames_window=int(sliding_time*FrameRate),flag_auto=True)
f_dff = cm.source_extraction.cnmf.utilities.detrend_df_f(A, b, C, f,YrA=None,quantileMin=10,frames_window=int(sliding_time*FrameRate),flag_auto=False)
#quantile_min:quantile used to estimate the baseline (values in [0,100])
#frames_window:number of frames for computing running quantile
#flag_auto: bool, flag for determining quantile automatically

# %%
#Num of qunalified components
num_components = A.shape[1]
print('The number of components is '+str(num_components))
#spatial components
i = 1#i-th compoment, which means i-th neurons
for i in range(num_components):
    plt.figure(); plt.imshow(np.reshape(A[:,i-1].toarray(), dims, order='F'))
    plt.title('Spatial components')
    #Temporal components
    plt.figure(); plt.plot(C[i-1])
    plt.title('Temporal components')
    plt.savefig(directory+'/preprocess/'+'temporal_'+filename+'_'+str(num_slice)+'_'+str(i)+'.jpg')
    #Deconvolved neural activity (spikes)
    #plt.figure();plt.plot(S[i-1,:])
    #DF/F normalized temporal compoment
    plt.figure();plt.plot(F_dff[i-1,:])
    plt.title('DF/F ')
    plt.savefig(directory+'/preprocess/'+'DF_F_'+filename+'_'+str(num_slice)+'_'+str(i)+'.jpg')
    #DF/F normalized temporal compoment without Residual components (lower noises)
    plt.figure();plt.plot(f_dff[i-1,:])
    plt.title('dF/F')#Without noise
    plt.savefig(directory+'/preprocess/'+'dF_F_'+filename+'_'+str(num_slice)+'_'+str(i)+'.jpg')
# Out:
# The number of components is 9
# /tmp/ipykernel_217372/1617985442.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(); plt.imshow(np.reshape(A[:,i-1].toarray(), dims, order='F'))
